# %% [markdown]
# # Topic ideas
#
# ---
#
# Group name: Felix Daubner
#
# ---
#
# *Replace the italic texts with your descriptions*

# %% [markdown]
# ## Steam Game Data
#
# ### Data source
#
# *State the source of the data set and describe when and how it was originally collected (by the original data curator, not necessarily how you found the data)*
# The Steam Data contains data about games on Steam, an online marketplace for computer games. The data was collected from the publicly available Steam Web API and steamspy.com around 7 years ago by Craig Kelly who provided the data on "data.world"
# https://data.world/craigkelly/steam-game-data
#
# ### Data characterisitcs
#
#  *Describe the observations and the general characteristics being measured in the data (note that the data needs to meet the  criteria described in the project description)*
#
#
#
# ### Research question
#
# *Describe a research question you're interested in answering using this data. State the response variable and possible predictor variables.*
# RecommendationCount, Metacritic, ScreenshotCount, SteamSpyOwners, SteamSpyPlayersEstimate, AchievementCount, IsFree, FreeVerAvail, PurchaseAvail, SubscriptionAvail, GenreIsX, PriceInitial, PriceFinal, ControllerSupport, DLCCount, CategoryX
#
# Regression: RecommendationCount
# Classification: Genre
#
# ### Overview of data
#
# *Use the Pandas functions to provide an overview of the data set*

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/games-features.csv")
df.head()
# Out:
#    QueryID  ResponseID                  QueryName               ResponseName  \
# 0       10          10             Counter-Strike             Counter-Strike
# 1       20          20      Team Fortress Classic      Team Fortress Classic
# 2       30          30              Day of Defeat              Day of Defeat
# 3       40          40         Deathmatch Classic         Deathmatch Classic
# 4       50          50  Half-Life: Opposing Force  Half-Life: Opposing Force
#
#   ReleaseDate  RequiredAge  DemoCount  DeveloperCount  DLCCount  Metacritic  \
# 0  Nov 1 2000            0          0               1         0          88
# 1  Apr 1 1999            0          0               1         0           0
# 2  May 1 2003            0          0               1         0          79
# 3  Jun 1 2001            0          0               1         0           0
# 4  Nov 1 1999            0          0               1         0           0
#
#    ...  LegalNotice  Reviews  \
# 0  ...
# ...

# %%
df.shape
# Out:
# (13357, 78)

# %%
df.dtypes.value_counts()
# Out:
# bool       35
# object     23
# int64      18
# float64     2
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13357 entries, 0 to 13356
# Data columns (total 78 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   QueryID                      13357 non-null  int64
#  1   ResponseID                   13357 non-null  int64
#  2   QueryName                    13356 non-null  object
#  3   ResponseName                 13357 non-null  object
#  4   ReleaseDate                  13357 non-null  object
#  5   RequiredAge                  13357 non-null  int64
#  6   DemoCount                    13357 non-null  int64
#  7   DeveloperCount               13357 non-null  int64
#  8   DLCCount                     13357 non-null  int64
#  9   Metacritic                   13357 non-null  int64
#  10  MovieCount                   13357 non-null  int64
#  11  PackageCount                 13357 non-null  int64
#  12  RecommendationCount          13357 non-null  int64
# ...

# %% [markdown]
# ## Name of topic idea 2
#
# ### Data source
#
# *State the source of the data set and describe when and how it was originally collected (by the original data curator, not necessarily how you found the data)*
# The European Social Survey (ESS), conducted in over 30 countries, aims to monitor changing public attitudes in Europe, improve cross-national survey methods, and develop social indicators. In its fifth round, funded by national contributors and supplemented by the European Science Foundation and City University in the UK, the survey employs strict random probability sampling and hour-long face-to-face interviews on core topics and specific modules.
#
# https://ess-search.nsd.no/en/study/fd0dc7b6-3d5a-42d4-ad46-7a78e44e3963
#
#
# ### Data characterisitcs
#
#  *Describe the observations and the general characteristics being measured in the data (note that the data needs to meet the  criteria described in the project description)*
# The survey involves strict random probability sampling, a minimum target response rate of 70% and rigorous translation protocols. The hour-long face-to-face interview includes questions on a variety of core topics repeated from previous rounds of the survey and also two modules developed for Round Five covering  Trust in the Police and Courts and Work, Family and Wellbeing (the latter is a partial repeat of a module from round 2).
#
# ### Research question
#
# *Describe a research question you're interested in answering using this data. State the response variable and possible predictor variables.*
# We would like to predict the Happiness-Score based on different variables like country, trust in politics, or socio-demographics.
#
# ### Overview of data
#
# *Use the Pandas functions to provide an overview of the data set*

# %%
df2 = pd.read_csv("../data/raw/ESS5e03_4.csv")
df2.head()
# Out:
#         name  essround  edition    proddate    idno cntry  dweight   pspwght  \
# 0  ESS5e03_4         5      3.4  01.12.2018  100102    BE      1.0  0.792865
# 1  ESS5e03_4         5      3.4  01.12.2018  100106    BE      1.0  0.871107
# 2  ESS5e03_4         5      3.4  01.12.2018  100202    BE      1.0  0.799453
# 3  ESS5e03_4         5      3.4  01.12.2018  100204    BE      1.0  0.816030
# 4  ESS5e03_4         5      3.4  01.12.2018  100209    BE      1.0  0.764902
#
#     pweight  tvtot  ...  inwyye  inwehh  inwemm  spltadmd  supqad1  supqad2  \
# 0  0.528619      5  ...  2010.0    14.0     2.0         3        6        1
# 1  0.528619      4  ...  2010.0    15.0    54.0         1        6        1
# 2  0.528619      4  ...  2010.0    14.0    46.0         1        6        1
# 3  0.528619      2  ...  2010.0    12.0     7.0         2        6        1
# 4  0.528619      7  ...  2010.0    14.0    48.0         3        6        1
#
#    supqdd  supqmm  supqyr  inwtm
# ...

# %%
df2["cntry"].unique()
# Out:
# array(['BE', 'BG', 'CH', 'CY', 'CZ', 'DE', 'DK', 'EE', 'ES', 'FI', 'FR',
#        'GB', 'GR', 'HR', 'HU', 'IE', 'IL', 'LT', 'NL', 'NO', 'PL', 'PT',
#        'RU', 'SE', 'SI', 'SK', 'UA'], dtype=object)

# %%
df2.shape
# Out:
# (52458, 674)

# %%
df2.dtypes.value_counts()
# Out:
# int64      354
# float64    310
# object      10
# Name: count, dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52458 entries, 0 to 52457
# Columns: 674 entries, name to inwtm
# dtypes: float64(310), int64(354), object(10)
# memory usage: 269.8+ MB

# %%
df2["happy"].value_counts()
# Out:
# happy
# 8     13239
# 7      9267
# 9      7491
# 5      6507
# 6      4787
# 10     4718
# 4      2249
# 3      1818
# 2       914
# 1       506
# 0       497
# 88      315
# 99      135
# 77       15
# Name: count, dtype: int64
